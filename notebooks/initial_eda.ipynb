# %% [markdown]
# First introduction to data, used as a tool to help us understand the data and the problem

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# Import data

# %%
cross_border_payments = pd.read_csv("../data/cross_border_payments.csv")
trade_finance = pd.read_csv("../data/trade_finance.csv")
transactional_banking = pd.read_csv("../data/transactional_banking.csv")

# %%
cross_border_payments.head()
# Out:
#   transaction_id entity_id      entity_name    sector        date direction  \
# 0    XBP63220455       E01        BHP Group    mining  2023-07-01   inbound
# 1    XBP14207725       E11  Pepkor Holdings  consumer  2023-07-01  outbound
# 2    XBP66460952       E11  Pepkor Holdings  consumer  2023-07-01  outbound
# 3    XBP45973312       E11  Pepkor Holdings  consumer  2023-07-01  outbound
# 4    XBP13173829       E11  Pepkor Holdings  consumer  2023-07-01   inbound
#
#   currency_pair   value_zar counterparty_country corridor_type  \
# 0       USD/ZAR  2541553.55          Switzerland  intercompany
# 1       USD/ZAR   407839.87               Angola  intercompany
# 2       CNY/ZAR    72148.47               Angola  intercompany
# 3       GBP/ZAR    53285.65              Namibia  intercompany
# 4       AED/ZAR  2858193.91                Japan         trade
#
#                 beneficiary_name       reference memo
# 0      BHP Group Switzerland Ltd  INTERCO-730855  NaN
# 1     Pepkor Holdings Angola Ltd  INTERCO-827118  NaN
# 2     Pepkor Holdings Angola Ltd  INTERCO-488519  NaN
# 3    Pepkor Holdings Namibia Ltd  INTERCO-585129  NaN
# 4  Continental Resources Trading    TRADE-568825  NaN

# %%
trade_finance.head()
# Out:
#   instrument_id entity_id      entity_name    sector        date  \
# 0    TF67401938       E01        BHP Group    mining  2023-07-01
# 1    TF91455580       E01        BHP Group    mining  2023-07-01
# 2    TF31370953       E10  Bid Corporation  consumer  2023-07-01
# 3    TF13634137       E10  Bid Corporation  consumer  2023-07-01
# 4    TF86438695       E10  Bid Corporation  consumer  2023-07-01
#
#      instrument_type direction  tenor_days    value_zar  counterparty_country  \
# 0  letters_of_credit    export          60  13499920.55  United Arab Emirates
# 1  letters_of_credit    export         365    558304.97           Switzerland
# 2  letters_of_credit    export          30   4042335.97        United Kingdom
# 3  letters_of_credit    import         365    171042.89                 China
# 4  letters_of_credit    export         120    331531.78           Netherlands
#
#   commodity_or_contract_type   status                     beneficiary_name  \
# 0               agri_produce   issued               Silverline Trading Co.
# 1                   iron_ore  settled         Global Commodities Marketing
# 2               agri_produce  settled  Pacific International Trading House
# 3      platinum_group_metals   active         Silverline Resources Trading
# 4                electronics  settled         Silverline Resources Trading
#
#    reference memo
# 0  LC-471415  NaN
# 1  LC-266865  NaN
# 2  LC-946978  NaN
# 3  LC-553503  NaN
# 4  LC-260628  NaN

# %%
transactional_banking.head()
# Out:
#   transaction_id entity_id      entity_name    sector        date  \
# 0    TXN40610803       E01        BHP Group    mining  2023-07-01
# 1    TXN12547643       E11  Pepkor Holdings  consumer  2023-07-01
# 2    TXN37710224       E11  Pepkor Holdings  consumer  2023-07-01
# 3    TXN65618575       E11  Pepkor Holdings  consumer  2023-07-01
# 4    TXN50222056       E11  Pepkor Holdings  consumer  2023-07-01
#
#             leg_type direction    amount_zar currency            channel  \
# 0        collections   inbound  63878.473869      ZAR                EFT
# 1  supplier_payments  outbound  53220.970000      ZAR                EFT
# 2  supplier_payments  outbound  12309.970000      ZAR              SWIFT
# 3  supplier_payments  outbound   6308.300000      ZAR  Internal Transfer
# 4  supplier_payments  outbound  55346.750000      ZAR  Internal Transfer
#
#                    beneficiary_name   reference memo
# 0  Continental Metals Trading House  INV-662227  NaN
# 1      Sunrise Cold Chain Logistics  INV-591371  NaN
# 2      Sunrise Cold Chain Logistics   PO-687736  NaN
# 3      Sunrise Cold Chain Logistics  INV-139304  NaN
# 4       Cape Wholesale Distributors  INV-556985  NaN
